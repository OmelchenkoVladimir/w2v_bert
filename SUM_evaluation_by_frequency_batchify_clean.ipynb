# %%
import ast
import math
import numpy as np
import pandas as pd
import gensim
import scipy
import torch
import torch.nn.functional as F
import pickle

from pytorch_transformers import BertTokenizer, BertModel, BertForMaskedLM, AdamW
from torch.utils.data import Dataset, DataLoader
from tensorboardX import SummaryWriter

#np.random.seed = 1
# Out:
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress

# %%
class BertToW2v(torch.nn.Module):
    def __init__(self, bert_model_name, lin_shape_in, lin_shape_out, emb_layer): # -, 768, 100, 6
        super(BertToW2v, self).__init__()
        self.emb_layer = emb_layer
        self.bert_model = BertModel.from_pretrained(bert_model_name, output_hidden_states=True)
        #self.bert_model.eval()
        self.linear_model = torch.nn.Linear(lin_shape_in, lin_shape_out, bias=True) # bias?
        torch.nn.init.uniform_(self.linear_model.weight, -0.1, 0.1)
        
    def forward(self, input_sentence, mask): # ожидаем уже токенизированное предложение
        _, _, encoded_layers = self.bert_model(input_sentence, attention_mask=mask)
        bert_output = encoded_layers[self.emb_layer][:,1]
        linear_output = self.linear_model(bert_output)
        return linear_output

# %%
ozhegov_emb = pd.read_csv('rus/ozhegov/ozhegov_emb.csv')[['word', 'definition']]
ozhegov_no_emb = pd.read_csv('rus/ozhegov/ozhegov_no_emb.csv')

dfreq = pd.read_csv('rusfreq/freqrnc2011.csv', sep = '\t')

model_name = 'batchify_ep20_l6_5_15'

# %%
with open('rus/freq/low_freq.pkl', 'rb') as f:
    ulfreq = pickle.load(file=f)
    
ozhegov = pd.concat([ozhegov_emb, ozhegov_no_emb], axis = 0)

ozhegov['lfreq'] = ozhegov['word'].apply(lambda word: word in ulfreq)

ozhegov_lfreq = ozhegov[ozhegov['lfreq'] == True][['word', 'definition']]

# %%
#defs = set(ozhegov_lfreq['word'])
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=False)
w2v = gensim.models.KeyedVectors.load_word2vec_format('w2v_models/all_norm-sz500-w10-cb0-it3-min5.w2v', binary=True, unicode_errors='ignore')

test = pd.read_csv('russe-evaluation/russe/evaluation/test.csv')

# %%
bw2v = BertToW2v('bert-base-multilingual-cased', lin_shape_in=768, lin_shape_out=500, emb_layer=6) # !!!
bw2v.load_state_dict(torch.load(f'models/{model_name}.mdl')) # !!!
bw2v.to('cuda');
bw2v.eval()
# Out:
# BertToW2v(
#   (bert_model): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(119547, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): BertLayerNorm()
#       (dropout): Dropout(p=0.1)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (linear_model): Linear(in_features=768, out_features=500, bias=True)
# )

# %%
test_words = pd.Series(np.hstack([test['word1'].unique(), test['word2'].unique()])).unique()

# %%
max_len = 128

def find_definition(word, dataset):
    try:
        return dataset[dataset['word'] == word].reset_index().iloc[0]['definition']
    except:
        return ''
    
def find_w2v(word, w2v):
    try:
        return w2v.get_vector(word)
    except KeyError:
        return np.nan
    
def get_bw2v(row, bw2v, tokenizer):
    if (row['defin'] == ''):
        return np.nan
    else:
        word = row['word']
        inp = row['input'].unsqueeze(0)
        attention = row['attention'].unsqueeze(0)
        inp = inp.to('cuda')
        attention = attention.to('cuda')
        with torch.no_grad():
            res = bw2v(inp, attention)
        return res.cpu()[0].numpy()

# %%
data = pd.DataFrame(pd.Series(np.hstack([test['word1'].unique(), test['word2'].unique()])).unique(), columns=['word'])

freq = pd.read_csv('rusfreq/freqrnc2011.csv', sep = '\t')

# %%
# %%time

data['defin'] = data['word'].apply(lambda x: find_definition(x, ozhegov))

data['w2v'] = data['word'].apply(lambda x: find_w2v(x, w2v))  # 307 nan'ов

data['input'] = data['defin'].apply(lambda x: torch.tensor(tokenizer.convert_tokens_to_ids(tokenizer.tokenize('[CLS] [MASK] - ' + x + ' [SEP]'))))

data['input'] = data['input'].apply(lambda x: F.pad(input=x, pad=(0, max_len-(x.shape[0])), mode='constant', value=0))

data['attention'] = data['input'].apply(lambda x: torch.tensor([float(el>0) for el in x]))

data['bw2v'] = data.apply(lambda x: get_bw2v(x, bw2v, tokenizer), axis=1)

data['freq'] = data['word'].apply(lambda x: freq[freq['Lemma'] == x]['Freq(ipm)'].max())
# Out:
# CPU times: user 1min 43s, sys: 113 ms, total: 1min 43s
# Wall time: 1min 43s

# %%
def numpy_nan(x):
    try:
        return math.isnan(x)
    except TypeError:
        return False

# %%
def get_result(row, threshold):
    row1 = data.iloc[(data[data['word'] == row['word1']]).index[0]]
    row2 = data.iloc[(data[data['word'] == row['word2']]).index[0]]
    if (row1['freq'] > threshold) and (row2['freq'] > threshold):
        if (numpy_nan(row1['w2v'])) or (numpy_nan(row2['w2v'])):
            return np.nan
        else:
            return 1 - scipy.spatial.distance.cosine(row1['w2v'], row2['w2v'])
    elif (row1['freq'] <= threshold) and (row2['freq'] > threshold):
        if ((numpy_nan(row1['w2v'])) and numpy_nan(row1['bw2v'])) or (numpy_nan(row2['w2v'])):
            return np.nan
        else:
            if (numpy_nan(row1['bw2v'])):
                return 1 - scipy.spatial.distance.cosine(row1['w2v'], row2['w2v'])
            else:
                return 1 - scipy.spatial.distance.cosine(row1['bw2v'], row2['w2v'])
    elif (row1['freq'] > threshold) and (row2['freq'] <= threshold):
        if ((numpy_nan(row2['w2v'])) and numpy_nan(row2['bw2v'])) or (numpy_nan(row1['w2v'])):
            return np.nan
        else:
            if (numpy_nan(row2['bw2v'])):
                return 1 - scipy.spatial.distance.cosine(row2['w2v'], row1['w2v'])
            else:
                return 1 - scipy.spatial.distance.cosine(row2['bw2v'], row1['w2v'])
    else:
        if ((numpy_nan(row2['w2v'])) and numpy_nan(row2['bw2v'])) or ((numpy_nan(row1['w2v'])) and numpy_nan(row1['bw2v'])):
            return np.nan
        else:
            if (numpy_nan(row1['bw2v'])) and (numpy_nan(row2['bw2v'])):
                return 1 - scipy.spatial.distance.cosine(row1['w2v'], row2['w2v'])
            elif (numpy_nan(row1['bw2v'])) and (not numpy_nan(row2['bw2v'])):
                return 1 - scipy.spatial.distance.cosine(row1['w2v'], row2['bw2v'])
            elif (not numpy_nan(row1['bw2v'])) and (numpy_nan(row2['bw2v'])):
                return 1 - scipy.spatial.distance.cosine(row1['bw2v'], row2['w2v'])
            else:
                return 1 - scipy.spatial.distance.cosine(row1['bw2v'], row2['bw2v'])

# %%
freq['percentile'] = pd.qcut(freq['Freq(ipm)'], 10, labels=False)

freqs_gb = freq.groupby(by='percentile')['Freq(ipm)'].max()

# %%
freqs_gb
# Out:
# percentile
# 0        0.5
# 1        0.7
# 2        0.9
# 3        1.3
# 4        1.9
# 5        2.8
# 6        4.3
# 7        7.7
# 8       20.0
# 9    35801.8
# Name: Freq(ipm), dtype: float64

# %%
for percentile in range(10):
    thresh = freqs_gb[percentile]
    sim = test.apply(lambda x: get_result(x, thresh), axis=1)
    test['sim'] = sim
    test['sim'] = test['sim'].fillna(test['sim'].mean())
    test.to_csv(f'russe-evaluation/russe/evaluation/{model_name}_percentile{(percentile*10+10)}.csv')

# %%
data
# Out:
#                    word                                              defin  \
# 0               абрикос  южное фруктовое дерево семейства розоцветных, ...
# 1              авангард  передовая, ведущая часть какой-нибудь обществе...
# 2                аватар
# 3              авиапорт
# 4         авиасообщение
# 5              австриец
# 6            автовокзал  большая станция пригородного или междугородног...
# 7              автограф                          подлинная рукопись автора
# 8            автодеталь
# 9          автокомбинат
# 10           автоматчик                     боец, вооруженный автоматом N2
# 11           автомобиль  транспортное средство на колесном (реже полугу...
# 12        автопогрузчик  самосдвижущаяся машина для погрузки, разгрузки...
# 13            автосалон
# 14          автотехника
# 15             агитация  активная деятельность по распространению полит...
# 16        агрессивность
# 17              агроном                            специалист по агрономии
# 18       агротехнология
# 19           адвокатура                                           адвокаты
# 20              адресат  тот, кому адресовано письмо, телеграмма, почто...
# 21                 ажур  такое ведение дел, при котором каждая операция...
# 22                азиат
# 23                  азы
# 24        аккомпанемент                          музыкальное сопровождение
# 25     аккомпанирование
# 26            акробатка
# 27              актриса  артист - исполнитель ролей в театральных предс...
# 28              албанка
# 29             алименты  материальное обеспечение, по закону предоставл...
# ...                 ...                                                ...
# 10537    судоустройство  система судебных учреждений, организация судеб...
# 10538            фемида
# 10539          ахматова
# 10540      виноградинка
# 10541          клубника       обиходное название крупной садовой земляники
# 10542            колыма
# 10543       наращивание
# 10544          шиповник  дикая кустарниковая роза с простыми (обычно не...
# 10545       ковалевский
# 10546         продтовар
# 10547           френсис
# 10548             яичко  помещающаяся в мошонке парная мужская половая ...
# 10549      яйцепродукты
# 10550     благоденствие                   спокойное и счастливое состояние
# 10551             исеть
# 10552        ялуторовск
# 10553          растаман
# 10554             регги
# 10555               апл
# 10556          ассириец
# 10557           ассирия
# 10558           балласт  сыпучий материал, которым покрывается земляное...
# 10559              гней
# 10560          загрузка  складывать груз куда-нибудь, помещать в качест...
# 10561          зверство                свойственный N2. свирепый, жестокий
# 10562             оковы  железные кольца с цепями, надеваемые на руки и...
# 10563              рона
# 10564             тацит
# 10565             хомут  приспособление кольцевой формы для скрепления,...
# 10566            сундук  тяжелый напольный ящик для хранения вещей с кр...
#
#                                                      w2v  \
# 0      [0.10378932, -0.14052582, 0.1942631, -0.305896...
# 1      [-0.15341343, -0.13074593, -0.051256265, 0.167...
# 2      [0.014951972, 0.0035384058, 0.24791141, 0.0169...
# 3      [-0.2978616, -0.4235942, 0.016439708, 0.116158...
# 4      [-0.37638554, 0.14005096, -0.050324634, 0.3548...
# 5      [-0.1491604, -0.27055186, 0.29353207, 0.142309...
# 6      [-0.4247384, -0.14860067, -0.023689255, -0.336...
# 7      [-0.294718, -0.30333897, 0.2978587, -0.0615298...
# 8      [-0.055288125, -0.12642151, -0.023027416, -0.0...
# 9      [0.0454641, 0.15902324, 0.058329105, -0.059688...
# 10     [-0.08755034, -0.09644887, 0.112432115, -0.108...
# 11     [-0.09366957, -0.1942923, 0.09219126, 0.139497...
# 12     [-0.13787559, -0.17838605, 0.09836723, 0.05852...
# 13     [-0.2102581, -0.16167405, -0.06479913, 0.29739...
# 14     [0.1111766, -0.08176235, -0.13452582, 0.161962...
# 15     [-0.07597931, 0.049412522, 0.05043018, -0.3911...
# 16     [-0.06950829, -0.03856111, -0.009077594, -0.00...
# 17     [-0.25601834, -0.3769442, 0.14181231, 0.285975...
# 18     [-0.14772834, -0.0392997, 0.08096669, 0.040021...
# 19     [-0.33287492, -0.11246757, -0.083520666, -0.27...
# 20     [-0.10529294, -0.07587534, 0.39892575, -0.0258...
# 21     [-0.37889385, 0.22926451, 0.35237798, -0.05184...
# 22     [-0.010472617, -0.04563273, 0.0049355756, -0.0...
# 23     [-0.03806381, 0.041822717, -0.13082495, 0.1877...
# 24     [-0.1123311, 0.2677263, 0.01691346, 0.18444061...
# 25     [-0.14547329, 0.16792251, 0.05795128, -0.10440...
# 26     [0.1770721, -0.07604495, 0.07250247, -0.161785...
# 27     [0.12222886, -0.2633966, 0.33280653, -0.057217...
# 28     [0.19752751, -0.14143713, -0.099623635, 0.0617...
# 29     [-0.2766632, 0.20504193, 0.39685065, 0.0686413...
# ...                                                  ...
# 10537  [-0.2946394, -0.11191362, -0.41589227, 0.27842...
# 10538  [0.10653824, -0.17373581, 0.20205444, -0.10184...
# 10539  [-0.10349614, -0.12237905, 0.2756916, -0.30524...
# 10540  [-0.0479381, -0.10015936, 0.3835805, -0.273130...
# 10541  [-0.008967026, -0.26380575, 0.18917455, 0.0241...
# 10542  [-0.26642337, -0.059468884, -0.0003927702, -0....
# 10543  [-0.23702139, 0.18300536, 0.26534587, -0.17214...
# 10544  [-0.24249357, -0.051656056, 0.47105652, -0.242...
# 10545  [-0.24553247, 0.036638044, 0.21572448, 0.02478...
# 10546                                                NaN
# 10547  [0.0619003, -0.04056588, -0.21241476, 0.152579...
# 10548  [0.010416238, -0.071255386, 0.25500047, -0.279...
# 10549  [-0.0900917, -0.063070945, 0.054277115, -0.109...
# 10550  [-0.07260028, 0.058571238, 0.017651, 0.1002334...
# 10551  [-0.23809682, -0.10022119, 0.07351521, -0.2089...
# 10552  [-0.1952804, -0.22409211, 0.27048814, 0.120949...
# 10553  [0.02142152, -0.26736864, -0.18111177, -0.3965...
# 10554  [0.077348, 0.09866621, -0.15333843, -0.0121600...
# 10555  [-0.33848557, 0.27235538, -0.28032562, -0.1850...
# 10556  [-0.055666342, -0.05201479, -0.039819267, 0.11...
# 10557  [-0.23312944, -0.06268555, 0.23541571, -0.0612...
# 10558  [-0.35885847, -0.15985522, 0.12392985, 0.24301...
# 10559  [0.018144803, 0.18257546, -0.0070261895, -0.44...
# 10560  [-0.1264141, -0.28230006, -0.11617718, -0.1120...
# 10561  [0.14888678, 0.13072194, -0.07177332, 0.289136...
# 10562  [-0.2380679, -0.11461084, -0.067188784, 0.2327...
# 10563  [-0.15673044, -0.06383399, -0.24654648, 0.1114...
# 10564  [0.0593565, 0.039243124, -0.23640072, -0.13718...
# 10565  [0.14748386, 0.059573986, 0.08186043, -0.05803...
# 10566  [0.013115354, -0.21874055, -0.18362314, -0.003...
#
#                                                    input  \
# 0      [tensor(101), tensor(103), tensor(118), tensor...
# 1      [tensor(101), tensor(103), tensor(118), tensor...
# 2      [tensor(101), tensor(103), tensor(118), tensor...
# 3      [tensor(101), tensor(103), tensor(118), tensor...
# 4      [tensor(101), tensor(103), tensor(118), tensor...
# 5      [tensor(101), tensor(103), tensor(118), tensor...
# 6      [tensor(101), tensor(103), tensor(118), tensor...
# 7      [tensor(101), tensor(103), tensor(118), tensor...
# 8      [tensor(101), tensor(103), tensor(118), tensor...
# 9      [tensor(101), tensor(103), tensor(118), tensor...
# 10     [tensor(101), tensor(103), tensor(118), tensor...
# 11     [tensor(101), tensor(103), tensor(118), tensor...
# 12     [tensor(101), tensor(103), tensor(118), tensor...
# 13     [tensor(101), tensor(103), tensor(118), tensor...
# 14     [tensor(101), tensor(103), tensor(118), tensor...
# 15     [tensor(101), tensor(103), tensor(118), tensor...
# 16     [tensor(101), tensor(103), tensor(118), tensor...
# 17     [tensor(101), tensor(103), tensor(118), tensor...
# 18     [tensor(101), tensor(103), tensor(118), tensor...
# 19     [tensor(101), tensor(103), tensor(118), tensor...
# 20     [tensor(101), tensor(103), tensor(118), tensor...
# 21     [tensor(101), tensor(103), tensor(118), tensor...
# 22     [tensor(101), tensor(103), tensor(118), tensor...
# 23     [tensor(101), tensor(103), tensor(118), tensor...
# 24     [tensor(101), tensor(103), tensor(118), tensor...
# 25     [tensor(101), tensor(103), tensor(118), tensor...
# 26     [tensor(101), tensor(103), tensor(118), tensor...
# 27     [tensor(101), tensor(103), tensor(118), tensor...
# 28     [tensor(101), tensor(103), tensor(118), tensor...
# 29     [tensor(101), tensor(103), tensor(118), tensor...
# ...                                                  ...
# 10537  [tensor(101), tensor(103), tensor(118), tensor...
# 10538  [tensor(101), tensor(103), tensor(118), tensor...
# 10539  [tensor(101), tensor(103), tensor(118), tensor...
# 10540  [tensor(101), tensor(103), tensor(118), tensor...
# 10541  [tensor(101), tensor(103), tensor(118), tensor...
# 10542  [tensor(101), tensor(103), tensor(118), tensor...
# 10543  [tensor(101), tensor(103), tensor(118), tensor...
# 10544  [tensor(101), tensor(103), tensor(118), tensor...
# 10545  [tensor(101), tensor(103), tensor(118), tensor...
# 10546  [tensor(101), tensor(103), tensor(118), tensor...
# 10547  [tensor(101), tensor(103), tensor(118), tensor...
# 10548  [tensor(101), tensor(103), tensor(118), tensor...
# 10549  [tensor(101), tensor(103), tensor(118), tensor...
# 10550  [tensor(101), tensor(103), tensor(118), tensor...
# 10551  [tensor(101), tensor(103), tensor(118), tensor...
# 10552  [tensor(101), tensor(103), tensor(118), tensor...
# 10553  [tensor(101), tensor(103), tensor(118), tensor...
# 10554  [tensor(101), tensor(103), tensor(118), tensor...
# 10555  [tensor(101), tensor(103), tensor(118), tensor...
# 10556  [tensor(101), tensor(103), tensor(118), tensor...
# 10557  [tensor(101), tensor(103), tensor(118), tensor...
# 10558  [tensor(101), tensor(103), tensor(118), tensor...
# 10559  [tensor(101), tensor(103), tensor(118), tensor...
# 10560  [tensor(101), tensor(103), tensor(118), tensor...
# 10561  [tensor(101), tensor(103), tensor(118), tensor...
# 10562  [tensor(101), tensor(103), tensor(118), tensor...
# 10563  [tensor(101), tensor(103), tensor(118), tensor...
# 10564  [tensor(101), tensor(103), tensor(118), tensor...
# 10565  [tensor(101), tensor(103), tensor(118), tensor...
# 10566  [tensor(101), tensor(103), tensor(118), tensor...
#
#                                                attention  \
# 0      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 1      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 2      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 3      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 4      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 5      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 6      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 7      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 8      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 9      [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 11     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 12     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 13     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 14     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 15     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 16     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 17     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 18     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 19     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 20     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 21     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 22     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 23     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 24     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 25     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 26     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 27     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 28     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 29     [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# ...                                                  ...
# 10537  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10538  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10539  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10540  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10541  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10542  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10543  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10544  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10545  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10546  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10547  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10548  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10549  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10550  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10551  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10552  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10553  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10554  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10555  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10556  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10557  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10558  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10559  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10560  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10561  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10562  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10563  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10564  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10565  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
# 10566  [tensor(1.), tensor(1.), tensor(1.), tensor(1....
#
#                                                     bw2v   freq
# 0      [-0.12012055, -0.10375254, 0.023982286, 0.0764...    3.3
# 1      [-0.120121464, -0.10375175, 0.023977919, 0.076...    9.8
# 2                                                    NaN    NaN
# 3                                                    NaN    NaN
# 4                                                    NaN    NaN
# 5                                                    NaN    2.6
# 6      [-0.12011934, -0.10375419, 0.02398602, 0.07646...    1.0
# 7      [-0.120118864, -0.103755176, 0.023987792, 0.07...   10.3
# 8                                                    NaN    NaN
# 9                                                    NaN    0.4
# 10     [-0.1201196, -0.10375388, 0.023985667, 0.07646...    4.5
# 11     [-0.120121874, -0.10375151, 0.023978584, 0.076...  156.9
# 12     [-0.120122544, -0.103750855, 0.023976477, 0.07...    NaN
# 13                                                   NaN    4.3
# 14                                                   NaN    NaN
# 15     [-0.12012077, -0.10375236, 0.023980761, 0.0764...    8.7
# 16                                                   NaN    4.2
# 17     [-0.120120384, -0.103753075, 0.023981664, 0.07...    5.4
# 18                                                   NaN    NaN
# 19     [-0.120119035, -0.10375461, 0.023986276, 0.076...    2.4
# 20     [-0.120119765, -0.103753775, 0.023985006, 0.07...    6.7
# 21     [-0.12012077, -0.10375258, 0.023981934, 0.0764...    1.0
# 22                                                   NaN    2.3
# 23                                                   NaN    NaN
# 24     [-0.1201196, -0.10375421, 0.023985215, 0.07646...    3.7
# 25                                                   NaN    NaN
# 26                                                   NaN    NaN
# 27     [-0.12011987, -0.10375348, 0.023983303, 0.0764...   40.4
# 28                                                   NaN    NaN
# 29     [-0.120120354, -0.103753075, 0.023983866, 0.07...    6.0
# ...                                                  ...    ...
# 10537  [-0.120119736, -0.103753775, 0.023984794, 0.07...    0.7
# 10538                                                NaN    NaN
# 10539                                                NaN    NaN
# 10540                                                NaN    NaN
# 10541  [-0.12011953, -0.103753924, 0.023985418, 0.076...    4.5
# 10542                                                NaN    NaN
# 10543                                                NaN    6.6
# 10544  [-0.120121054, -0.10375206, 0.023980768, 0.076...    4.0
# 10545                                                NaN    NaN
# 10546                                                NaN    NaN
# 10547                                                NaN    NaN
# 10548  [-0.12012095, -0.10375209, 0.023980863, 0.0764...    5.5
# 10549                                                NaN    NaN
# 10550  [-0.1201205, -0.103753224, 0.023982465, 0.0764...    2.2
# 10551                                                NaN    NaN
# 10552                                                NaN    NaN
# 10553                                                NaN    0.4
# 10554                                                NaN    NaN
# 10555                                                NaN    NaN
# 10556                                                NaN    0.4
# 10557                                                NaN    NaN
# 10558  [-0.12012055, -0.103752464, 0.023982346, 0.076...    1.8
# 10559                                                NaN    NaN
# 10560  [-0.120122455, -0.1037505, 0.02397442, 0.07646...    7.3
# 10561  [-0.12011831, -0.10375537, 0.023990093, 0.0764...    3.1
# 10562  [-0.12012065, -0.10375297, 0.023982238, 0.0764...    2.1
# 10563                                                NaN    NaN
# 10564                                                NaN    NaN
# 10565  [-0.12012063, -0.10375266, 0.02398151, 0.07646...    2.2
# 10566  [-0.12012145, -0.10375187, 0.023979532, 0.0764...   12.5
#
# [10567 rows x 7 columns]

# %%
row = data.iloc[21]

# %%
row['defin']
# Out:
# 'такое ведение дел, при котором каждая операция регистрируется немедленно после ее совершения'

# %%
word = row['word']
inp = row['input'].unsqueeze(0)
attention = row['attention'].unsqueeze(0)
inp = inp.to('cuda')
attention = attention.to('cuda')

# %%
x = 'такое ведение дел, при котором каждая операция регистрируется немедленно после ее совершения'
inp = torch.tensor([tokenizer.convert_tokens_to_ids(tokenizer.tokenize('[CLS] [CLS]' + x + '[SEP]'))]).to('cuda')

# %%
with torch.no_grad():
    _, _, tmp  = bw2v.bert_model(inp)

# %%
tmp
# Out:
# (tensor([[[-0.4456,  0.0627, -0.1807,  ...,  0.4191, -0.4707,  0.1631],
#           [-0.4584, -0.0287,  0.4728,  ...,  0.6191, -0.6317,  0.0543],
#           [-0.1495,  0.4490, -0.4619,  ...,  0.1357,  0.4095, -1.4835],
#           ...,
#           [-0.9577,  0.5846, -0.7484,  ..., -0.3848, -0.6820,  0.3802],
#           [-0.7268,  0.7438,  0.7163,  ...,  0.4393, -0.4528, -0.6298],
#           [ 0.6444,  0.8613,  1.1060,  ..., -0.0604,  0.8569, -0.2070]]],
#         device='cuda:0'),
#  tensor([[[ 0.3961, -0.1015, -0.9602,  ..., -0.6380, -0.4597,  1.6722],
#           [ 0.4232, -0.1048, -0.9306,  ..., -0.6701, -0.4992,  1.7689],
#           [ 0.4018, -0.0315, -1.1045,  ..., -0.7215, -0.3786,  1.7110],
#           ...,
#           [ 0.3745, -0.0692, -1.1252,  ..., -0.7881, -0.4482,  1.8852],
#           [ 0.3728, -0.1073, -1.0238,  ..., -0.7000, -0.4310,  1.7903],
#           [ 0.4850, -0.0590, -0.9849,  ..., -0.7394, -0.4821,  1.7925]]],
#         device='cuda:0'),
#  tensor([[[ 0.3661,  1.0728,  0.1908,  ...,  0.0406,  0.7601, -0.2118],
#           [ 0.3645,  1.0798,  0.2007,  ...,  0.0372,  0.8114, -0.2117],
#           [ 0.3844,  1.1082,  0.1633,  ...,  0.0273,  0.8878, -0.2343],
#           ...,
#           [ 0.3746,  1.1062,  0.1685,  ...,  0.0147,  0.8874, -0.2236],
#           [ 0.3727,  1.0948,  0.1913,  ...,  0.0250,  0.8757, -0.2315],
#           [ 0.3813,  1.0959,  0.1898,  ...,  0.0214,  0.8799, -0.2199]]],
#         device='cuda:0'),
#  tensor([[[ 0.9788,  0.0637,  0.3314,  ..., -0.4500, -0.6790, -0.0891],
#           [ 0.9796,  0.0638,  0.3321,  ..., -0.4493, -0.6741, -0.0905],
#           [ 0.9821,  0.0644,  0.3294,  ..., -0.4490, -0.6689, -0.0939],
#           ...,
#           [ 0.9816,  0.0633,  0.3297,  ..., -0.4498, -0.6689, -0.0935],
#           [ 0.9807,  0.0642,  0.3304,  ..., -0.4499, -0.6694, -0.0931],
#           [ 0.9814,  0.0629,  0.3316,  ..., -0.4494, -0.6687, -0.0930]]],
#         device='cuda:0'),
#  tensor([[[-0.4939, -0.7681,  0.2314,  ...,  0.3659,  0.4446,  0.4166],
#           [-0.4939, -0.7682,  0.2316,  ...,  0.3658,  0.4447,  0.4164],
#           [-0.4938, -0.7681,  0.2317,  ...,  0.3658,  0.4449,  0.4161],
#           ...,
#           [-0.4938, -0.7682,  0.2318,  ...,  0.3658,  0.4448,  0.4161],
#           [-0.4938, -0.7681,  0.2317,  ...,  0.3658,  0.4449,  0.4161],
#           [-0.4938, -0.7682,  0.2318,  ...,  0.3658,  0.4449,  0.4162]]],
#         device='cuda:0'),
#  tensor([[[ 0.1201, -0.2393,  0.4480,  ...,  0.0025, -0.1397,  0.2173],
#           [ 0.1201, -0.2393,  0.4480,  ...,  0.0025, -0.1397,  0.2173],
#           [ 0.1201, -0.2393,  0.4480,  ...,  0.0025, -0.1397,  0.2173],
#           ...,
#           [ 0.1201, -0.2393,  0.4480,  ...,  0.0025, -0.1397,  0.2173],
#           [ 0.1201, -0.2393,  0.4480,  ...,  0.0025, -0.1397,  0.2173],
#           [ 0.1201, -0.2393,  0.4480,  ...,  0.0025, -0.1397,  0.2173]]],
#         device='cuda:0'),
#  tensor([[[ 0.0188,  0.0223,  0.0688,  ..., -0.0534,  0.0175,  0.0506],
#           [ 0.0188,  0.0223,  0.0688,  ..., -0.0534,  0.0175,  0.0506],
#           [ 0.0188,  0.0223,  0.0688,  ..., -0.0534,  0.0175,  0.0506],
#           ...,
#           [ 0.0188,  0.0223,  0.0688,  ..., -0.0534,  0.0175,  0.0506],
#           [ 0.0188,  0.0223,  0.0688,  ..., -0.0534,  0.0175,  0.0506],
#           [ 0.0188,  0.0223,  0.0688,  ..., -0.0534,  0.0175,  0.0506]]],
#         device='cuda:0'),
#  tensor([[[-0.0071,  0.2247,  0.0501,  ..., -0.1374, -0.1597,  0.1574],
#           [-0.0071,  0.2247,  0.0501,  ..., -0.1374, -0.1597,  0.1574],
#           [-0.0071,  0.2247,  0.0501,  ..., -0.1374, -0.1597,  0.1574],
#           ...,
#           [-0.0071,  0.2247,  0.0501,  ..., -0.1374, -0.1597,  0.1574],
#           [-0.0071,  0.2247,  0.0501,  ..., -0.1374, -0.1597,  0.1574],
#           [-0.0071,  0.2247,  0.0501,  ..., -0.1374, -0.1597,  0.1574]]],
#         device='cuda:0'),
#  tensor([[[ 0.0189,  0.0048,  0.0308,  ..., -0.2081,  0.1602,  0.1416],
#           [ 0.0189,  0.0048,  0.0308,  ..., -0.2081,  0.1602,  0.1416],
#           [ 0.0189,  0.0048,  0.0308,  ..., -0.2081,  0.1602,  0.1416],
#           ...,
#           [ 0.0189,  0.0048,  0.0308,  ..., -0.2081,  0.1602,  0.1416],
#           [ 0.0189,  0.0048,  0.0308,  ..., -0.2081,  0.1602,  0.1416],
#           [ 0.0189,  0.0048,  0.0308,  ..., -0.2081,  0.1602,  0.1416]]],
#         device='cuda:0'),
#  tensor([[[-0.0211,  0.0620,  0.0757,  ..., -0.2027,  0.1181,  0.0846],
#           [-0.0211,  0.0620,  0.0757,  ..., -0.2027,  0.1181,  0.0846],
#           [-0.0211,  0.0620,  0.0757,  ..., -0.2027,  0.1181,  0.0846],
#           ...,
#           [-0.0211,  0.0620,  0.0757,  ..., -0.2027,  0.1181,  0.0846],
#           [-0.0211,  0.0620,  0.0757,  ..., -0.2027,  0.1181,  0.0846],
#           [-0.0211,  0.0620,  0.0757,  ..., -0.2027,  0.1181,  0.0846]]],
#         device='cuda:0'),
#  tensor([[[ 0.0198, -0.0472,  0.0425,  ..., -0.1857, -0.0306,  0.0811],
#           [ 0.0198, -0.0472,  0.0425,  ..., -0.1857, -0.0306,  0.0811],
#           [ 0.0198, -0.0472,  0.0425,  ..., -0.1857, -0.0306,  0.0811],
#           ...,
#           [ 0.0198, -0.0472,  0.0425,  ..., -0.1857, -0.0306,  0.0811],
#           [ 0.0198, -0.0472,  0.0425,  ..., -0.1857, -0.0306,  0.0811],
#           [ 0.0198, -0.0472,  0.0425,  ..., -0.1857, -0.0306,  0.0811]]],
#         device='cuda:0'),
#  tensor([[[ 0.0020, -0.0288,  0.0867,  ..., -0.1585, -0.0304,  0.0444],
#           [ 0.0020, -0.0288,  0.0867,  ..., -0.1585, -0.0304,  0.0444],
#           [ 0.0020, -0.0288,  0.0867,  ..., -0.1585, -0.0304,  0.0444],
#           ...,
#           [ 0.0020, -0.0288,  0.0867,  ..., -0.1585, -0.0304,  0.0444],
#           [ 0.0020, -0.0288,  0.0867,  ..., -0.1585, -0.0304,  0.0444],
#           [ 0.0020, -0.0288,  0.0867,  ..., -0.1585, -0.0304,  0.0444]]],
#         device='cuda:0'),
#  tensor([[[ 0.3389, -0.5223,  0.2609,  ..., -0.0346,  0.0026, -0.3453],
#           [ 0.3389, -0.5223,  0.2609,  ..., -0.0346,  0.0026, -0.3453],
#           [ 0.3389, -0.5223,  0.2609,  ..., -0.0346,  0.0026, -0.3453],
#           ...,
#           [ 0.3389, -0.5223,  0.2609,  ..., -0.0346,  0.0026, -0.3453],
#           [ 0.3389, -0.5223,  0.2609,  ..., -0.0346,  0.0026, -0.3453],
#           [ 0.3389, -0.5223,  0.2609,  ..., -0.0346,  0.0026, -0.3453]]],
#         device='cuda:0'))

# %%
tmp2 = tmp[2][6][:,1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-9e615e0ba28f> in <module>()
# ----> 1 tmp2 = tmp[2][6][:,1]
#
# IndexError: index 6 is out of bounds for dimension 0 with size 1

# %%
bw2v.linear_model(tmp2)
