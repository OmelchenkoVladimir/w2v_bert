# %%
import numpy as np
import pandas as pd

import gensim
import scipy
import torch
from pytorch_pretrained_bert import BertTokenizer, BertModel, BertForMaskedLM
# Out:
# paramiko missing, opening SSH/SCP/SFTP paths will be disabled.  `pip install paramiko` to suppress

# %%
class BertToW2v(torch.nn.Module):
    def __init__(self, bert_model_name, lin_shape_in, lin_shape_out, emb_layer): # -, 768, 100, 6
        super(BertToW2v, self).__init__()
        self.emb_layer = emb_layer
        self.bert_model = BertModel.from_pretrained(bert_model_name)
        #self.bert_model.eval()
        self.linear_model = torch.nn.Linear(lin_shape_in, lin_shape_out, bias=True) # bias?
        torch.nn.init.uniform_(self.linear_model.weight, -0.1, 0.1)
        
    def forward(self, input_sentence): # ожидаем уже токенизированное предложение
        encoded_layers, _ = self.bert_model(input_sentence)
        bert_output = encoded_layers[self.emb_layer][0][1]
        linear_output = self.linear_model(bert_output).unsqueeze(0)
        return linear_output

# %%
ozhegov_lfreq = pd.read_csv('rus/ozhegov/ozhegov_no_emb.csv')
defs = set(ozhegov_lfreq['word'])
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased', do_lower_case=False)
w2v = gensim.models.KeyedVectors.load_word2vec_format('w2v_models/all_norm-sz500-w10-cb0-it3-min5.w2v', binary=True, unicode_errors='ignore')

test = pd.read_csv('russe-evaluation/russe/evaluation/test.csv')

# %%
bw2v = BertToW2v('bert-base-multilingual-cased', lin_shape_in=768, lin_shape_out=500, emb_layer=6)
bw2v.load_state_dict(torch.load('models/SUM_5epochs_hyphen.mdl'))
bw2v.to('cuda');

# %%
def find_embedding(word, model, w2v, ozhegov_lfreq, defs, tokenizer):
    if word in defs:
        print(word)
        print('IN DEFS')
        defin = ozhegov_lfreq[ozhegov_lfreq['word'] == word].reset_index()['definition'][0]
        defin = '[CLS] [MASK] - ' + defin + ' [SEP]'
        tokens = tokenizer.tokenize(defin)
        tok_ids = torch.tensor([tokenizer.convert_tokens_to_ids(tokens)]).to('cuda')
        with torch.no_grad():
            embedding = model(tok_ids)
        return embedding.to('cpu').numpy()
    else:
        try:
            return w2v.get_vector(word)
        except KeyError:
            return np.nan
        
def get_cosine_distance(word1, word2, model, w2v, ozhegov_lfreq, defs, tokenizer):
    emb1 = find_embedding(word1, model, w2v, ozhegov_lfreq, defs, tokenizer)
    emb2 = find_embedding(word2, model, w2v, ozhegov_lfreq, defs, tokenizer)
    if (np.isnan(np.sum(emb1)) or np.isnan(np.sum(emb2))):
        return np.nan
    return 1 - scipy.spatial.distance.cosine(emb1, emb2)

assert abs(get_cosine_distance('абрикос', 'год', bw2v, w2v, ozhegov_lfreq, defs, tokenizer) - (1 - w2v.distance('абрикос', 'год'))) < 0.000001

# %%
get_cosine_distance('диск-жокей', 'зачем-то', bw2v, w2v, ozhegov_lfreq, defs, tokenizer)
# Out:
# диск-жокей
# IN DEFS
# зачем-то
# IN DEFS
# 0.7680607438087463

# %%
defin = ozhegov_lfreq[ozhegov_lfreq['word'] == 'зачем-то'].reset_index()['definition'][0]
defin = '[CLS] [MASK] - ' + defin + ' [SEP]'
tokens = tokenizer.tokenize(defin)
tok_ids = torch.tensor([tokenizer.convert_tokens_to_ids(tokens)]).to('cuda')

# %%
with torch.no_grad():
    tmp = bw2v.bert_model(tok_ids)

# %%
test['sim'] = test.apply(lambda row: get_cosine_distance(row['word1'], row['word2'], bw2v, w2v, ozhegov_lfreq, defs, tokenizer), axis=1)
# Out:
# юго-восток
# IN DEFS
# северо-запад
# IN DEFS
# премьер-министр
# IN DEFS
# гамма-излучение
# IN DEFS
# северо-запад
# IN DEFS
# гран-при
# IN DEFS
# генерал-губернатор
# IN DEFS
# иван-чай
# IN DEFS
# иван-да-марья
# IN DEFS
# иван-чай
# IN DEFS
# иван-чай
# IN DEFS
# иван-чай
# IN DEFS
# юго-восток
# IN DEFS
# юго-запад
# IN DEFS
# кока-кола
# IN DEFS
# кока-кола
# IN DEFS
# кока-кола
# IN DEFS
# кока-кола
# IN DEFS
# премьер-министр
# IN DEFS
# пресс-конференция
# IN DEFS
# рок-н-ролл
# IN DEFS
# социал-демократия
# IN DEFS
# статс-секретарь
# IN DEFS
# гран-при
# IN DEFS

# %%
test['sim'] = test['sim'].fillna(test['sim'].mean())

# %%
test.to_csv('russe-evaluation/russe/evaluation/SUM_model.csv', index=None)

# %%
ozhegov_lfreq.shape
# Out:
# (1209, 2)

# %%
ozhegov_lfreq
# Out:
#                          word  \
# 0     образцово-показательный
# 1                     гено...
# 2               покапризичать
# 3                  издохнуть.
# 4                  диск-жокей
# 5                 куда-нибудь
# 6               иван-да-марья
# 7                испакостить.
# 8               медно-красный
# 9                вспучить,-ся
# 10                    шеф-...
# 11               покапываться
# 12                  слабо....
# 13                     вз...I
# 14                    иCпанка
# 15                столько-то.
# 16                    под...I
# 17                  интерьер.
# 18                 пресс-бюро
# 19                      у...I
# 20                    низо...
# 21               тысячеустный
# 22                    сель...
# 23                 алкаголизм
# 24                утолститься
# 25                   торфо...
# 26              откуда-нибудь
# 27         научно-технический
# 28                  солнце...
# 29                интермедия.
# ...                       ...
# 1179             обмуровочный
# 1180             который-либо
# 1181                в-десятых
# 1182                  невеять
# 1183                 какой-то
# 1184                 гайморов
# 1185                     а...
# 1186             вице-адмирал
# 1187                 где-либо
# 1188                   хим...
# 1189               когда-либо
# 1190                    то-то
# 1191                  двух...
# 1192            неадекватный.
# 1193                   взъ...
# 1194              выкарабться
# 1195        казаки-разбойники
# 1196                    каре.
# 1197            прохавиваться
# 1198             обмачиваться
# 1199           прима-беларина
# 1200                   воз...
# 1201                 черно...
# 1202                талмудитс
# 1203          меланходический
# 1204                  индекс.
# 1205                дальне...
# 1206             автомоделист
# 1207               прогрудеть
# 1208              раздушиться
#
#                                              definition
# 0     образцовый и предназначенный для показа, для п...
# 1                                   относящийся к генам
# 2                  капризничать некоторое время, слегка
# 3                                            <= д¦хнуть
# 4                         ведущий программу в дискотеке
# 5              безразлично куда; в неопределенное место
# 6     травянистое растение с желтыми цветками и фиол...
# 7                                          <= пакостить
# 8                      имеющий цвет меди, желто-красный
# 9                                             <= пучить
# 10                                     главный, старший
# 11                                       <= подкопаться
# 12                                            слабый N1
# 13                                                    +
# 14                                           <= испанцы
# 15                                                    +
# 16                                                    +
# 17            внутреннее пространство здания, помещения
# 18    постоянно дейятвующий орган информации при ред...
# 19                                                    +
# 20                                            == низ...
# 21        относящийся к бесчисленному множеству голосов
# 22                                             сельский
# 23    тяжелое хроническое заболевание, вызываемое зл...
# 24                               стать толстым N1 толще
# 25                  относящийся к торфу, к добыче торфа
# 26    из какого-нибудь неопределенного места, источника
# 27                        относящийся к науке и технике
# 28                                 похожий на солнце N1
# 29    комическая пьеска, исполняемая между актами др...
# ...                                                 ...
# 1179                            <= муровать и обмуровка
# 1180                                  == который-нибудь
# 1181                                                  +
# 1182                                  вея N3 наготовить
# 1183                не заслуживающий внимания, уважения
# 1184                                                 =>
# 1185                                              == не
# 1186  второе адмиральское звание или чин во флоте, р...
# 1187                                      == где-нибудь
# 1188                    относящийся к химии, химический
# 1189                                    == когда-нибудь
# 1190                                                  +
# 1191                                          <= дву...
# 1192  не совпадающий с чем-нибудь, лишенный адекватн...
# 1193                                           == вз...
# 1194                       карабкаясь, выйти, выбраться
# 1195  детская игра, в которой одна группа преследует...
# 1196                           в форме четырехугольника
# 1197                                        <= пройтись
# 1198                                        <= обмочить
# 1199                  балерина, исполняющая первые роли
# 1200                                                  +
# 1201  относящийся к черным землям, к черному крестья...
# 1202   начетчик, схоластически рассуждающий человек Lib
# 1203                                      <= меланхолия
# 1204  условное обозначение в системе какой-нибудь кл...
# 1205                  далекий N1, с далекого расстояния
# 1206                 человек, занимающийся автомоделизм
# 1207                                          <= гудеть
# 1208                                  сильно надушиться
#
# [1209 rows x 2 columns]
